# %%
import math
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# The following code is for recap on derivatives
#
# let f(x)
#
# f'(x) = (f(x + h) - f(x)) / h
# where h is a small constant

# %%
def f(x):
    return 3*x**2 + 2*x + 1

# %%
x = np.arange(-5, 2, 0.25)
y = f(x)

plt.plot(x, y)

# %%
h = 0.001 # small constant

# for a point on f(x), the derivative at that point is
# e.g. x = -2.5
x = -2.5

# derivative
(f(x + h) - f(x)) / h
# Out:
# -12.997000000002146

# %%
def grad(x, func):
    h = 0.001
    return (f(x + h) - f(x)) / h

def line(x1, y1, grad):
    x = np.linspace(-6, 0)
    y = grad*(x - x1) + y1
    plt.plot(x, y, color='red')
    
    # start and stop values of x values 
    # manually chosen
    x = np.arange(-5, 2, 0.25)
    y = f(x)

    plt.plot(x, y)

# %%
line(x, f(x),  grad(x, f))
